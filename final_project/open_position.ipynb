# %%
import os, sys


import re
import matplotlib as plt
from matplotlib import pyplot
import pandas as pd
import numpy as np
import seaborn as sns
import bs4
import requests
import string

sys.path.append('/home/jason/MDST/webscraping/utils/')
from soup import getSoup

page = 'https://mymakar.github.io/'
soup  = getSoup(page)

# %%
df_prof = pd.read_csv('data/dummy_cse.csv')
df_prof.head()
# Out:
#                  name                                              title  \
# 0      Bansal, Nikhil  Patrick C. Fischer Professor of Theoretical Co...
# 1        Bodwin, Greg  Assistant Professor, Electrical Engineering & ...
# 2   Cheraghchi, Mahdi  Associate Professor, Electrical Engineering an...
# 3   Compton, Kevin J.  Associate Professor Emeritus, Electrical Engin...
# 4  Dereziński, Michał  Assistant Professor, Electrical Engineering an...
#
#                email                    lab  \
# 0  bansaln@umich.edu             ['theory']
# 1   bodwin@umich.edu             ['theory']
# 2  mahdich@umich.edu             ['theory']
# 3      kjc@umich.edu  ['theory', 'systems']
# 4  derezin@umich.edu       ['theory', 'ai']
#
#                                            interests  \
# 0  ['Algorithms', 'Optimization', 'Machine Learni...
# 1  ['Graph Algorithms', 'Data Structures', 'Sketc...
# 2  ['Information And Coding Theory', 'Cryptograph...
# ...

# %%
# for ind, row in df_prof.iterrows():
#     site = row['site']

#     has_research = function(site)

#     row['research'] = has_research

# %%
# df_prof.to_csv('data/cse_research')
